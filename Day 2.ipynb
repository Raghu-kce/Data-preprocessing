# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dh1=pd.read_csv("/content/i1.csv")
dh2=pd.read_csv("/content/i2.csv")

# %%
dh=dh1.merge(dh2,how='outer')
dh
# Out:
#              Date            Timestamp  Invoice No.  \
# 0      2023-04-01  2023-04-01 13:16:03        23465
# 1      2023-04-01  2023-04-01 13:16:03        23465
# 2      2023-04-01  2023-04-01 13:16:03        23465
# 3      2023-04-01  2023-04-01 13:16:03        23465
# 4      2023-04-01  2023-04-01 13:16:03        23465
# ...           ...                  ...          ...
# 15616  2023-09-19  2023-09-19 22:03:44        28389
# 15617  2023-09-19  2023-09-19 22:03:44        28389
# 15618  2023-09-19  2023-09-19 22:03:44        28389
# 15619  2023-09-19  2023-09-19 22:03:44        28389
# 15620  2023-09-19  2023-09-19 22:03:44        28389
#
#                          Item Name  Price  Qty.  Sub Total  Discount    Tax  \
# 0              Babycorn Manchurian  160.0   1.0      160.0       0.0   8.00
# 1                Chicken Kati Roll  120.0   1.0      120.0       0.0   6.00
# 2             Paneer Butter Masala  150.0   2.0      300.0       0.0  15.00
# ...

# %%
dh.shape
# Out:
# (15621, 16)

# %%
dh.describe()
# Out:
#         Invoice No.         Price          Qty.     Sub Total      Discount  \
# count  15621.000000  15621.000000  15621.000000  15621.000000  15621.000000
# mean   25989.963127    116.608988      1.338839    147.407080      1.262818
# std     1433.192998     63.663769      0.949814    210.127442      6.656396
# min    23465.000000     12.000000      1.000000     12.000000      0.000000
# 25%    24751.000000     50.000000      1.000000     80.000000      0.000000
# 50%    25980.000000    140.000000      1.000000    150.000000      0.000000
# 75%    27274.000000    160.000000      1.000000    170.000000      0.000000
# max    28389.000000    770.000000     28.000000  21560.000000    288.000000
#
#                 Tax   Final Total     Table No.   Covers  HSN
# count  15621.000000  15621.000000  15613.000000  15621.0  0.0
# mean       7.303668    153.447930     18.068340      0.0  NaN
# std       10.461474    219.678163     17.191377      0.0  NaN
# ...

# %%
dh.isnull()
# Out:
#         Date  Timestamp  Invoice No.  Item Name  Price   Qty.  Sub Total  \
# 0      False      False        False      False  False  False      False
# 1      False      False        False      False  False  False      False
# 2      False      False        False      False  False  False      False
# 3      False      False        False      False  False  False      False
# 4      False      False        False      False  False  False      False
# ...      ...        ...          ...        ...    ...    ...        ...
# 15616  False      False        False      False  False  False      False
# 15617  False      False        False      False  False  False      False
# 15618  False      False        False      False  False  False      False
# 15619  False      False        False      False  False  False      False
# 15620  False      False        False      False  False  False      False
#
#        Discount    Tax  Final Total  Table No.  Server Name  Covers  \
# ...

# %%
dh['Final Total'].sum()
# Out:
# np.float64(2397010.12)

# %%
dh['Invoice No.'].nunique()
# Out:
# 4925

# %%
a=dh.groupby('Item Name')['Qty.'].sum().sort_values(ascending=False)[0:5]

# %%
sns.barplot(a)
# Out:
# <Axes: xlabel='Item Name', ylabel='Qty.'>

# %%
a.plot(kind='bar')
# Out:
# <Axes: xlabel='Item Name'>

# %%
b=a=dh.groupby('Item Name')['Final Total'].sum().sort_values(ascending=False)[0:10]

# %%
b.plot(kind='bar')
# Out:
# <Axes: xlabel='Item Name'>

# %%
d=dh.groupby('Date')['Final Total'].sum().sort_values(ascending=False)

# %%
d
# Out:
# Date
# 2023-04-13    31154.64
# 2023-05-19    29690.16
# 2023-06-09    27167.70
# 2023-08-11    24271.78
# 2023-06-10    24243.19
#                 ...
# 2023-06-05     5948.16
# 2023-06-28     5796.04
# 2023-07-03     5414.88
# 2023-06-20     5247.88
# 2023-05-02     3489.18
# Name: Final Total, Length: 171, dtype: float64

# %%
e=dh.loc[(dh['Date']=='2023=09=15')& (dh['Item Name']=='Chicken Noodles'),'Qty.'].sum()

# %%
e
# Out:
# np.float64(0.0)

# %%
f=dh.groupby('Invoice No.')['Final Total'].sum()
f[f>2000]
# Out:
# Invoice No.
# 23499     2533.64
# 23508     2011.00
# 23637     5644.82
# 23718     3517.50
# 23827    22638.00
#            ...
# 28014     3013.68
# 28126     2887.50
# 28145     4078.68
# 28259     4291.36
# 28315     2004.44
# Name: Final Total, Length: 162, dtype: float64

# %%
o=dh.loc[dh['Invoice No.'] == 28145, ['Item Name', 'Final Total', 'Qty.']].sum()

# %%
o
# Out:
# Item Name      Butter Chicken GravyButter Chicken GravyButter...
# Final Total                                              4078.68
# Qty.                                                        40.0
# dtype: object

# %%
from wordcloud import WordCloud
text=''.join(dh['Item Name'].dropna().astype(str).values)
wordcloud=WordCloud(background_color='white',width=1000,height=600).generate(text)
fig,ax=plt.subplots(figsize=(10,6))
ax.imshow(wordcloud,interpolation='nearest')
ax.set_title('word clod of Item Colmn')
ax.set_xticks([])
ax.set_yticks([])
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text=''.join(dh['Item Name'].dropna().astype(str).values)
wordcloud=WordCloud(background_color='white',width=1000,height=600).generate(text)
fig,ax=plt.subplots(figsize=(10,6))
ax.imshow(wordcloud,interpolation='bicubic') # Changed interpolation method to 'bicubic'
ax.set_title('word cloud of Item Column')
ax.set_xticks([])
ax.set_yticks([])
plt.show()

# %%
from wordcloud import WordCloud
text=''.join(dh['Item Name'].dropna().astype(str).values)
wordcloud=WordCloud(background_color='white',width=1000,height=600).generate(text)
fig,ax=plt.subplots(figsize=(10,6))
ax.imshow(wordcloud,interpolation='nearest')
ax.set_title('word clod of Item Colmn')
ax.set_xticks([])
ax.set_yticks([])
plt.show()
